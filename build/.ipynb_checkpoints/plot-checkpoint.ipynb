# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("all_23_solenoids.csv")

# %%
data.head()
# Out:
#            x           y        z        bx        by         bz particle  \
# 0  39.548391  -77.272125   1230.0  0.144705 -0.282734  20.469558      pi+
# 1  68.828793  167.553097   5110.5  0.096862  0.235794   7.872907      pi+
# 2 -94.377951 -172.349036   9360.0 -0.053127 -0.097017   3.149163      pi+
# 3  58.087819  458.009355  13240.0  0.032698  0.257819   3.149163      pi+
# 4  80.295331 -115.092095  17490.0  0.045199 -0.064787   3.149163      pi+
#
#         energy                  volume
# 0  1288.390394  Solenoid_1_FieldVolume
# 1  1287.609156  Solenoid_1_FieldVolume
# 2  1286.924920  Solenoid_1_FieldVolume
# 3  1286.223997  Solenoid_1_FieldVolume
# 4  1284.812793  Solenoid_1_FieldVolume

# %%
z = np.array(data['z'].to_list())
bz = np.array(data['bz'].to_list())
bx = np.array(data['bx'].to_list())
by = np.array(data['by'].to_list())
b_mod = np.array(np.sqrt(bx**2 + by**2 + bz**2))
particles = np.array(data['particle'].to_list())
energy = np.array(data['energy'].to_list())
print(b_mod
     )
# Out:
# [20.47202195  7.8770328   3.15110495 ...  9.46439154  4.74302643
#   3.149163  ]

# %%
len(bz), len(z)
# Out:
# (8328, 8328)

# %%
bin_size = 800  # mm
z_min = np.min(z)
z_max = np.max(z)

bin_edges = np.arange(z_min, z_max + bin_size, bin_size)

peak_bz = []
bin_centers = []

# Loop through bins
for i in range(len(bin_edges) - 1):
    z_start = bin_edges[i]
    z_end = bin_edges[i + 1]
    
    # Get indices within the bin
    mask = (z >= z_start) & (z < z_end)
    
    if np.any(mask):
        peak = np.max(np.abs(bz[mask]))
        peak_bz.append(peak)
        bin_centers.append((z_start + z_end) / 2)

# %%
plt.figure(figsize=(8, 4))
plt.plot(bin_centers, peak_bz, marker='o', linestyle='-')
plt.xlabel('z position (mm)')
plt.ylabel('Peak Bz (T)')
plt.title('Peak Bz Field in Every 1000 mm')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pi_plus_pos = []
pi_plus_energy = []
pi_minus = []
mu_plus = []
mu_minus = []
for i in range(0, len(particles)):
    if particles[i] == "pi+":
        pi_plus_energy.append(energy[i])
        pi_plus_pos.append(z[i])

# %%
Bi = 20
Bf = 1.5
Lt = 18200
# -1< z < Lt
B = []

z_list = [i for i in range(-1000, 18201)] 

for zi in z_list:
    B_temp = (Bi*Bf*(Lt**3))/(Bi*(zi**2)*(3*Lt-2*zi)+Bf*((Lt-zi)**2)*(2*zi+Lt))
    B.append(B_temp)
    
plt.plot(z_list, B, color='red', label='Original Points')
plt.scatter(z, bz, marker='o', linestyle='-')
#plt.plot(bin_centers, peak_bz, marker='o', linestyle='-')
plt.xlabel('z position (mm)')
plt.ylabel('Bz (T)')
#plt.plot(z_smooth, bz_smooth, 'g-', label='Polynomial Fit')
plt.show()

# %%
data = pd.read_csv("6D_vector.csv")
data.head()
# Out:
#    Detector ParticleType     x[cm]  px[MeV/c]     y[cm]  py[MeV/c]    z[cm]  \
# 0         1          pi+  -1.57274  122.26700   7.59049   234.4810   449.95
# 1         2          pi+ -22.08990   -5.61699  15.72890   266.8840  1109.95
# 2         3          pi+   7.83022 -262.22600 -11.51690   -10.1067  1749.95
# 3         1          mu+  17.78140  239.10700  15.95210   179.9640   449.95
# 4         1          pi+ -12.84330 -173.92400 -18.73440   -42.5946   449.95
#
#    pz[MeV/c]  TotalEnergy[MeV]
# 0   1252.440          1148.070
# 1   1250.720          1146.910
# 2   1249.820          1145.110
# 3    268.884           310.299
# 4    225.098           180.137

# %%
det = np.array(data['Detector'].to_list())
particle = np.array(data['ParticleType'].to_list())
px = np.array(data['px[MeV/c]'].to_list())
py = np.array(data['py[MeV/c]'].to_list())
pz = np.array(data['pz[MeV/c]'].to_list())
x = np.array(data['x[cm]'].to_list())
y = np.array(data['y[cm]'].to_list())
z = np.array(data['z[cm]'].to_list())
det1_particles = []
det1_px = []
det1_py = []
det1_pz = []
det1_x = []
det1_y = []
det1_z = []
det2_particles = []
det2_px = []
det2_py = []
det2_pz = []
det2_x = []
det2_y = []
det2_z = []
det3_particles = []
det3_px = []
det3_py = []
det3_pz = []
det3_x = []
det3_y = []
det3_z = []

# %%
for i in range(0, len(det)):
    if det[i] == 1:
        det1_particles.append(particle[i])
        det1_px.append(px[i])
        det1_py.append(py[i])
        det1_pz.append(pz[i])
        det1_x.append(x[i])
        det1_y.append(y[i])
        det1_z.append(z[i])
    elif det[i] == 2:
        det2_particles.append(particle[i])
        det2_px.append(px[i])
        det2_py.append(py[i])
        det2_pz.append(pz[i])
        det2_x.append(x[i])
        det2_y.append(y[i])
        det2_z.append(z[i])
    elif det[i] == 3:
        det3_particles.append(particle[i])
        det3_px.append(px[i])
        det3_py.append(py[i])
        det3_pz.append(pz[i])
        det3_x.append(x[i])
        det3_y.append(y[i])
        det3_z.append(z[i])

len(det3_particles)
# Out:
# 1129

# %%
from collections import Counter

counts = Counter(det1_particles)
categories1 = list(counts.keys())
values1 = list(counts.values())

# %%
counts = Counter(det2_particles)
categories2 = list(counts.keys())
values2 = list(counts.values())

# %%
counts = Counter(det3_particles)
categories3 = list(counts.keys())
values3 = list(counts.values())

# %%
 len(det3_particles)
# Out:
# 1129

# %%
plt.scatter(det1_x,det1_y )
plt.xlabel("x [cm]")
plt.ylabel("px [MeV/c]")
plt.show()

# %%
plt.scatter(det3_x,det3_y )
plt.xlabel("x [cm]")
plt.ylabel("y [cm]")
plt.show()

# %%
plt.scatter(det3_x,det3_px )
plt.xlabel("x [cm]")
plt.ylabel("px [MeV/c]")
plt.show()

# %%
def compute_and_plot_emittance(x_list, px_list, pz_list):
    # Convert lists to numpy arrays
    x = np.array(x_list)
    px = np.array(px_list)
    pz = np.array(pz_list)
    
    # Compute x' = px / pz
    xp = px / pz

    # Center data
    x_mean = np.mean(x)
    xp_mean = np.mean(xp)
    x_c = x - x_mean
    xp_c = xp - xp_mean

    # Compute statistical moments
    x2 = np.mean(x_c**2)
    xp2 = np.mean(xp_c**2)
    xxp = np.mean(x_c * xp_c)

    # Calculate geometric emittance
    emittance = np.sqrt(x2 * xp2 - xxp**2)
    print(f"Geometric Emittance: {emittance:.3e} mm")

    # Plotting phase space
    
    plt.scatter(x, xp)
    plt.xlabel("x [mm]")
    plt.ylabel("x' [rad]")
    plt.title("Transverse Phase Space (x vs x')")
    plt.grid(True)
    plt.axis('equal')
    plt.show()

    return emittance

# %%
det_pos = [4, 10.5, 17.5] # in meters

# %%
colors = ['red', 'blue', 'green', 'brown']

# Number of sets
n_sets = 3
x = np.arange(n_sets)  # One x-position per set
width = 0.2            # Width of each bar

plt.figure(figsize=(10, 6))

# Keep track of all BarContainers so we can annotate them afterward
all_bars = []

for i, (particle, color) in enumerate(zip(categories1, colors)):
    values = [values1[i], values2[i], values3[i]]
    bars = plt.bar(x + i * width, values, width=width, label=particle, color=color)
    all_bars.append(bars)

# Annotate each bar with its height
for bars in all_bars:
    for bar in bars:
        height = bar.get_height()
        plt.text(
            bar.get_x() + bar.get_width() / 2,  # x position: center of the bar
            height + 1,                         # y position: just above the bar
            f'{int(height)}',                   # the label
            ha='center', va='bottom',
            fontsize=10                          # tweak as needed
        )

# X-axis setup
plt.xticks(
    x + width * 1.5,
    ['Detector 1 (z = 4.5 m)', 'Detector 2 (z = 11 m)', 'Detector 3 (z = 17.7 m)'],
    fontsize=12,
)

plt.legend(title='Particles')
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
len(det1_x)
# Out:
# 2042

# %%
len(det2_x)
# Out:
# 1316

# %%
len(det3_x)
# Out:
# 1129

# %%
p_transverse = np.array(np.sqrt(np.array(np.array(det2_px)*np.array(det2_px))+np.array(np.array(det2_py)*np.array(det2_py))))

# %%
larmor_radius = np.array(p_transverse/(1.5*300))

# %%
larmor_radius
# Out:
# array([0.39150503, 0.34524284, 0.47078491, ..., 0.26516061, 0.48398162,
#        0.17446863])

# %%
r_max = 0.7
test = []
for rl in larmor_radius:
    if(rl>r_max):
        test.append('hit')
    else:
        test.append('pass')

# %%
count = Counter(test)
categories = list(count.keys())
freq = list(count.values())
plt.bar(categories, freq)
plt.show()
